# %%
import pandas as pd

data={
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

df=pd.DataFrame(data,index=['Day1','Day2','Day3'])
print(df)
print("\n")
print(df.loc['Day2'])
# Out:
#        cars  passings
# Day1    BMW         3
# Day2  Volvo         7
# Day3   Ford         2
#
#
# cars        Volvo
# passings        7
# Name: Day2, dtype: object

# %%
cpi=pd.read_excel("C:/Users/Tenzin Choeyang D/OneDrive/Desktop/predictive analysis/rbi/Consumer Price Index.xlsx")
cpi['Date']=pd.to_datetime(cpi['Date'])
print(cpi)
# Out:
#           Date Consumer Price Index   Inflation_Rate
# 0   2025-10-31                 197.3            0.25
# 1   2025-09-30                   197            1.44
# 2   2025-08-31                   197            2.07
# 3   2025-07-31                 196.1            1.61
# 4   2025-06-30                 194.2            2.10
# ..         ...                   ...             ...
# 230        NaT                     -             NaN
# 231        NaT                     -             NaN
# 232        NaT                     -             NaN
# 233        NaT                     -             NaN
# 234        NaT                     -             NaN
#
# [235 rows x 3 columns]

# %%
usd = pd.read_excel("C:/Users/Tenzin Choeyang D/OneDrive/Desktop/predictive analysis/rbi/Exchange Rate of the Indian Rupee.xlsx")
usd["Date"]=pd.to_datetime(usd["Date"])
usd.rename(columns={'US Dollar': 'USD_INR'},inplace=True)
print(usd)
# Out:
#           Date    USD_INR
# 0   2025-10-31  88.416400
# 1   2025-09-30  88.322590
# 2   2025-08-31  87.518389
# 3   2025-07-31  86.114622
# 4   2025-06-30  85.903433
# ..         ...        ...
# 322 1998-12-31  42.549264
# 323 1998-11-30  42.381520
# 324 1998-10-31  42.331824
# 325 1998-09-30  42.517828
# 326 1998-08-31  42.523633
#
# [327 rows x 2 columns]
